# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("credit_dataset_5000_enhanced_final.csv")

# %%
print(df.head())
# Out:
#    Age  Income  Coapplicant_Income  Dependents  Employ_Status   Debt  \
# 0   61   26587               10296           1       Employed  56824
# 1   36   23236               13264           3  Self-employed  78620
# 2   66   19245               32648           5       Employed  34596
# 3   29   64148               19563           1       Employed  59612
# 4   43  101424               49221           1     Unemployed   1523
#
#    PrevLDefault  CIBIL_Score  Loan_Approval
# 0             1          465              0
# 1             1          456              1
# 2             0          572              0
# 3             0          620              0
# 4             0          659              0

# %%
df['Employ_Status'].unique()
# Out:
# array(['Employed', 'Self-employed', 'Unemployed'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Income                0
# Coapplicant_Income    0
# Dependents            0
# Employ_Status         0
# Debt                  0
# PrevLDefault          0
# CIBIL_Score           0
# Loan_Approval         0
# dtype: int64

# %%
df['PrevLDefault'].unique()
# Out:
# array([1, 0])

# %%
(df['Loan_Approval'] == 0).sum()
# Out:
# np.int64(2504)

# %%
(df['Loan_Approval'] == 1).sum()
# Out:
# np.int64(2496)

# %%
sns.displot(
    data=df,
    x="Debt",
    hue="Loan_Approval",
    kind="kde"
)

# %%
sns.displot(
    data=df,
    x="PrevLDefault",
    hue="Loan_Approval",
    kind="kde"
)

# %%
sns.displot(
    data=df,
    x="CIBIL_Score",
    hue="Loan_Approval",
    kind="kde"
)

# %%
sns.displot(
    data=df,
    x="Income",
    hue="Loan_Approval",
    kind="kde"
)

# %%
sns.heatmap(pd.crosstab(df['CIBIL_Score'],df['Loan_Approval']))
# Out:
# <Axes: xlabel='Loan_Approval', ylabel='CIBIL_Score'>

# %%
pd.crosstab(df['PrevLDefault'], df['Loan_Approval'])
# Out:
# Loan_Approval     0     1
# PrevLDefault
# 0              1236  1266
# 1              1268  1230

# %%
df
# Out:
#       Age  Income  Coapplicant_Income  Dependents  Employ_Status   Debt  \
# 0      61   26587               10296           1       Employed  56824
# 1      36   23236               13264           3  Self-employed  78620
# 2      66   19245               32648           5       Employed  34596
# 3      29   64148               19563           1       Employed  59612
# 4      43  101424               49221           1     Unemployed   1523
# ...   ...     ...                 ...         ...            ...    ...
# 4995   33   76196               76786           3  Self-employed  80218
# 4996   32   93373                5342           0  Self-employed  78488
# 4997   57   21445               25752           4     Unemployed  27510
# 4998   58   34367               47047           3     Unemployed   2577
# 4999   59  149442               54600           4  Self-employed  97275
#
#       PrevLDefault  CIBIL_Score  Loan_Approval
# 0                1          465              0
# 1                1          456              1
# 2                0          572              0
# 3                0          620              0
# 4                0          659              0
# ...            ...          ...            ...
# 4995             1          445              0
# 4996             1          471              1
# 4997             1          481              0
# 4998             1          476              1
# 4999             1          394              1
#
# [5000 rows x 9 columns]

# %%
np.random.seed(42)

# %%
score = (
    (df['CIBIL_Score'] - df['CIBIL_Score'].mean()) / df['CIBIL_Score'].std() * 2.5
    - df['PrevLDefault'] * 0.0          # removed - it's ~-0.91 correlated with CIBIL_Score already
    - (df['Debt'] / df['Income'].replace(0, np.nan).fillna(df['Income'].mean())) * 0.8
    + (df['Income'] - df['Income'].mean()) / df['Income'].std() * 1.3
    - df['Dependents'] * 0.1
    + np.where(df['Employ_Status'] == 'Employed', 2.0,
        np.where(df['Employ_Status'] == 'Self-employed', 2.2, -2.0))
)

# %%
threshold = score.median()
df['Loan_Approval'] = (score > threshold).astype(int)

print(df['Loan_Approval'].value_counts(normalize=True))
# Out:
# Loan_Approval
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['Loan_Approval']),df['Loan_Approval'],
                                                test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       Age  Income  Coapplicant_Income  Dependents  Employ_Status   Debt  \
# 4227   46   59919               66406           4  Self-employed   6322
# 4676   38  148339                1214           1  Self-employed  44037
# 800    65   86447               10673           2       Employed   2395
# 3671   68   99438               85982           4     Unemployed  67552
# 4193   50   65202               79154           4     Unemployed  27458
# ...   ...     ...                 ...         ...            ...    ...
# 4426   65   86874               74766           3     Unemployed   1521
# 466    37  103570               42480           0     Unemployed  75027
# 3092   26   56099               55221           1       Employed  33205
# 3772   35  146002               16101           3     Unemployed  73533
# 860    53   47700               56930           0       Employed  27562
#
#       PrevLDefault  CIBIL_Score
# 4227             1          448
# 4676             0          569
# 800              0          613
# 3671             1          440
# 4193             1          427
# ...            ...          ...
# 4426             1          447
# 466              1          467
# 3092             1          487
# 3772             0          580
# 860              1          485
#
# [4000 rows x 8 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
trf1 = ColumnTransformer([
    ('employ_status',
     OrdinalEncoder(categories=[['Unemployed', 'Employed', 'Self-employed']],
                     handle_unknown='use_encoded_value',
                     unknown_value=-1),
     [4])
], remainder='passthrough')

result = trf1.fit_transform(X_train)
result1=trf1.fit_transform(X_test)
Employment_train = pd.DataFrame(result, columns=trf1.get_feature_names_out())
Employment_test = pd.DataFrame(result1,columns=trf1.get_feature_names_out())
print(Employment_train)
# Out:
#       employ_status__Employ_Status  remainder__Age  remainder__Income  \
# 0                              2.0            46.0            59919.0
# 1                              2.0            38.0           148339.0
# 2                              1.0            65.0            86447.0
# 3                              0.0            68.0            99438.0
# 4                              0.0            50.0            65202.0
# ...                            ...             ...                ...
# 3995                           0.0            65.0            86874.0
# 3996                           0.0            37.0           103570.0
# 3997                           1.0            26.0            56099.0
# 3998                           0.0            35.0           146002.0
# 3999                           1.0            53.0            47700.0
#
#       remainder__Coapplicant_Income  remainder__Dependents  remainder__Debt  \
# 0                           66406.0                    4.0           6322.0
# 1                            1214.0                    1.0          44037.0
# 2                           10673.0                    2.0           2395.0
# 3                           85982.0                    4.0          67552.0
# 4                           79154.0                    4.0          27458.0
# ...                             ...                    ...              ...
# 3995                        74766.0                    3.0           1521.0
# 3996                        42480.0                    0.0          75027.0
# 3997                        55221.0                    1.0          33205.0
# 3998                        16101.0                    3.0          73533.0
# 3999                        56930.0                    0.0          27562.0
#
#       remainder__PrevLDefault  remainder__CIBIL_Score
# 0                         1.0                   448.0
# 1                         0.0                   569.0
# 2                         0.0                   613.0
# 3                         1.0                   440.0
# 4                         1.0                   427.0
# ...                       ...                     ...
# 3995                      1.0                   447.0
# 3996                      1.0                   467.0
# 3997                      1.0                   487.0
# 3998                      0.0                   580.0
# 3999                      1.0                   485.0
#
# [4000 rows x 8 columns]

# %%
Employment_train.columns = [col.replace("remainder__", "").replace("employ_status__", "") 
                            for col in Employment_train.columns]
Employment_test.columns = [col.replace("remainder__", "").replace("employ_status__", "") 
                           for col in Employment_test.columns]

# %%
Employment_train
# Out:
#       Employ_Status   Age    Income  Coapplicant_Income  Dependents     Debt  \
# 0               2.0  46.0   59919.0             66406.0         4.0   6322.0
# 1               2.0  38.0  148339.0              1214.0         1.0  44037.0
# 2               1.0  65.0   86447.0             10673.0         2.0   2395.0
# 3               0.0  68.0   99438.0             85982.0         4.0  67552.0
# 4               0.0  50.0   65202.0             79154.0         4.0  27458.0
# ...             ...   ...       ...                 ...         ...      ...
# 3995            0.0  65.0   86874.0             74766.0         3.0   1521.0
# 3996            0.0  37.0  103570.0             42480.0         0.0  75027.0
# 3997            1.0  26.0   56099.0             55221.0         1.0  33205.0
# 3998            0.0  35.0  146002.0             16101.0         3.0  73533.0
# 3999            1.0  53.0   47700.0             56930.0         0.0  27562.0
#
#       PrevLDefault  CIBIL_Score
# 0              1.0        448.0
# 1              0.0        569.0
# 2              0.0        613.0
# 3              1.0        440.0
# 4              1.0        427.0
# ...            ...          ...
# 3995           1.0        447.0
# 3996           1.0        467.0
# 3997           1.0        487.0
# 3998           0.0        580.0
# 3999           1.0        485.0
#
# [4000 rows x 8 columns]

# %%
sns.displot(
    data=df,
    x="CIBIL_Score",
    hue="Loan_Approval",
    kind="kde"
)

# %%
sns.displot(
    data=df,
    x="PrevLDefault",
    hue="Loan_Approval",
    kind="kde"
)

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,      
    max_depth=6,           
    min_samples_leaf=10,
    random_state=42
)
rf_model.fit(Employment_train, y_train)
y_pred = rf_model.predict(Employment_test)
print('Train accuracy:', accuracy_score(y_train, rf_model.predict(Employment_train)))
print('Test accuracy :', accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# Out:
# Train accuracy: 0.97525
# Test accuracy : 0.967
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       507
#            1       0.97      0.96      0.97       493
#
#     accuracy                           0.97      1000
#    macro avg       0.97      0.97      0.97      1000
# weighted avg       0.97      0.97      0.97      1000

# %%
print("Accuracy",accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy 96.7

# %%
from sklearn.model_selection import cross_val_score
model = RandomForestClassifier()
print("Training",np.mean(cross_val_score(model,Employment_train,y_train,scoring='accuracy',cv=10))*100)
print("Testing",np.mean(cross_val_score(model,Employment_test,y_test,scoring='accuracy',cv=10))*100)
# Out:
# Training 97.7
# Testing 97.00000000000001

# %%
importances = pd.Series(
    rf_model.feature_importances_,
    index=Employment_train.columns
).sort_values(ascending=False)

print(importances)
# Out:
# CIBIL_Score           0.328210
# Income                0.226467
# Employ_Status         0.206884
# PrevLDefault          0.170420
# Debt                  0.027800
# Dependents            0.023862
# Coapplicant_Income    0.009174
# Age                   0.007183
# dtype: float64
